# %% [markdown]
# <a href="https://colab.research.google.com/github/santiagoconfa/tutorialgit/blob/dev/Hola_mundo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hola mundo")
# Out:
# hola mundo

# %% [markdown]
# Otro PRINT  como prueba

# %% [markdown]
# comentario para prueba

# %%
print("esto es una prueba")
# Out:
# esto es una prueba
